# %%
###### import numpy as np
import matplotlib.pyplot as plt
import SKIF_lib as skf
import numpy as np
import os

station = '1_4'

SKIF_path = skf.get_SKIF_directory() #get SKIF project root directory
TablesPath = skf.path_in_project('/' + station + '/TechReports/tabl/')#, your_sys='Mac OC')
FigPath = skf.path_in_project('/' + station + '/TechReports/pic/')
wfrPath = skf.path_in_project('/' + station + '/fields_' + station + '/')
#Diamond_T_path = skf.path_in_project('/' + station + '/crystals_data_' + station + '/diamond_T/')
#Diamond_R_path = skf.path_in_project('/' + station + '/crystals_data_' + station + '/diamond_R/')
file_path = SKIF_path + '/SypPy_examp/'

def read_und(file_path=None, file_name=None):
    
    if file_path is None:
        file_path = '/home/andrei/Documents/SKIF_XAS_beamline/1_2/crystals_data_1_2/diamond_T/'

    f = open(file_path+file_name,"r")
    lines=f.readlines()
    X=[]
    Y=[]
    for x in lines:
        X.append(float(x.split('\t')[0]))
        Y.append(float(x.split('\t')[1]))
    f.close()
    
    return(np.array(X), np.array(Y))

X_, Y_ = read_und(file_path=file_path, file_name='1-4.txt')
# Out:
# Your project name is /home/andrei/Documents/SKIF_XAS_beamline
#  edit the skf.get_SKIF_directory if it is needed

# %%
plt.figure(figsize=(1.5*10,1.5*3))

ax1 = plt.subplot(211)
plt.subplots_adjust(wspace=-0.5, hspace=0.01)
plt.semilogy(X_, Y_, color='blue')

y = plt.ylabel(r'$Поток, \; \gamma/сек/0.1\%bw$', fontsize=18, labelpad = 0.0, rotation=0)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)


#plt.xticks([],
#           [], fontsize=16)

plt.yticks([1e10,1e11,1e12,1e13,1e14],
          [r'$1e^{10}$', r'$1e^{11}$', r'$1e^{12}$', r'$1e^{13}$',r'$1e^{14}$'], fontsize=14)
#leg = plt.legend(fontsize=12)#loc='upper left')
# Get the bounding box of the original legend
#

file_path = SKIF_path + FigPath + 'bragg_T.pdf'

plt.grid()
plt.ylim(0)
plt.xlim(0, 40000)

ax2 = plt.subplot(212, sharex=ax)
plt.plot(X_, Y_, color='blue')

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)

plt.yticks([1e14, 2e14],
          [r'$1e^{14}$', r'$2e^{14}$'], fontsize=14)
plt.xticks([5000, 10000, 15000, 20000, 25000, 30000, 35000],
           [r'$5$', r'$10$', r'$15$', r'$20$', r'$25$', r'$30$', r'$35$'],
           fontsize=14)


plt.xlabel(r'$E, кэВ$', fontsize=18, labelpad = 0.0)
y.set_rotation(90)

plt.ylim(0)
plt.xlim(0, 40000)
plt.grid()
file = SKIF_path + '/SypPy_examp/log_spec_1-4.pdf'
plt.savefig(file)#, bbox_inches='tight')
plt.savefig('/home/andrei/Documents/diploma/TexPresent/pic/log_spec_1-4.pdf')
# Out:
# /home/andrei/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3291: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %%
file_path = SKIF_path + '/SypPy_examp/'
X_, Y_ = read_und(file_path=file_path, file_name='1-1.txt')

# %%
plt.figure(figsize=(1.5*10,1.5*3))

ax1 = plt.subplot(211)
plt.subplots_adjust(wspace=-0.5, hspace=0.01)
plt.semilogy(X_, Y_, color='blue')

y = plt.ylabel(r'$Поток, \; \gamma/сек/0.1\%bw$', fontsize=18, labelpad = 0.0, rotation=0)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)


#plt.xticks([],
#           [], fontsize=16)

plt.yticks([1e10,1e11,1e12,1e13,1e14],
          [r'$1e^{10}$', r'$1e^{11}$', r'$1e^{12}$', r'$1e^{13}$',r'$1e^{14}$'], fontsize=14)
#leg = plt.legend(fontsize=12)#loc='upper left')
# Get the bounding box of the original legend
#

file_path = SKIF_path + FigPath + 'bragg_T.pdf'

plt.grid()
plt.ylim(0)
plt.xlim(0, 40000)

ax2 = plt.subplot(212, sharex=ax)
plt.plot(X_, Y_, color='blue')

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)

plt.yticks([1e14, 2e14, 3e14, 4e14, 5e14],
          [r'$1e^{14}$', r'$2e^{14}$', r'$3e^{14}$', r'$4e^{14}$', r'$5e^{14}$'], fontsize=14)
plt.xticks([5000, 10000, 15000, 20000, 25000, 30000, 35000],
           [r'$5$', r'$10$', r'$15$', r'$20$', r'$25$', r'$30$', r'$35$'],
           fontsize=14)


plt.xlabel(r'$E, кэВ$', fontsize=18, labelpad = 0.0)
y.set_rotation(90)

plt.ylim(0)
plt.xlim(0, 40000)
plt.grid()
file = SKIF_path + '/SypPy_examp/log_spec_1-1.pdf'
plt.savefig(file)#, bbox_inches='tight')
plt.savefig('/home/andrei/Documents/diploma/TexPresent/pic/log_spec_1-1.pdf')
# Out:
# /home/andrei/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3291: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %%
file_path = SKIF_path + '/SypPy_examp/'
X_, Y_ = read_und(file_path=file_path, file_name='1-2.txt')

# %%
plt.figure(figsize=(1.5*10,1.5*3))

ax1 = plt.subplot(211)
plt.subplots_adjust(wspace=-0.5, hspace=0.01)
plt.semilogy(X_, Y_, color='blue')

y = plt.ylabel(r'$Поток, \; \gamma/сек/0.1\%bw$', fontsize=18, labelpad = 0.0, rotation=0)

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)


#plt.xticks([],
#           [], fontsize=16)

plt.yticks([1e9, 1e10,1e11,1e12,1e13,1e14],
          [r'$1e^{9}$',r'$1e^{10}$', r'$1e^{11}$', r'$1e^{12}$', r'$1e^{13}$',r'$1e^{14}$'], fontsize=14)
#leg = plt.legend(fontsize=12)#loc='upper left')
# Get the bounding box of the original legend
#

file_path = SKIF_path + FigPath + 'bragg_T.pdf'

plt.grid()
plt.ylim(1e9, 5e14)
plt.xlim(0, 40000)

ax2 = plt.subplot(212, sharex=ax)
plt.plot(X_, Y_, color='blue')

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['top'].set_position(('axes',0))
ax.yaxis.set_ticks_position('left')
ax.spines['top'].set_position(('data',0))
ax.xaxis.set_label_coords(0.97, -0.06)
ax.yaxis.set_label_coords(-0.06, -0.1)

plt.yticks([1e14, 2e14, 3e14, 4e14, 5e14],
          [r'$1e^{14}$', r'$2e^{14}$', r'$3e^{14}$', r'$4e^{14}$', r'$5e^{14}$'], fontsize=14)
plt.xticks([5000, 10000, 15000, 20000, 25000, 30000, 35000],
           [r'$5$', r'$10$', r'$15$', r'$20$', r'$25$', r'$30$', r'$35$'],
           fontsize=14)


plt.xlabel(r'$E, кэВ$', fontsize=18, labelpad = 0.0)
y.set_rotation(90)

plt.ylim(0)
plt.xlim(0, 40000)
plt.grid()
file = SKIF_path + '/SypPy_examp/log_spec_1-2.pdf'
plt.savefig(file)#, bbox_inches='tight')
plt.savefig('/home/andrei/Documents/diploma/TexPresent/pic/log_spec_1-2.pdf')
